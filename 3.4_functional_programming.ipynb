// %% [markdown]
// <a name="top"></a><img src="images/chisel_1024.png" alt="Chisel logo" style="width:480px;" />

// %% [markdown]
// # Module 3.4: Functional Programming
// **Prev: [Higher-Order Functions](3.3_higher-order_functions.ipynb)**<br>
// **Next: [Object Oriented Programming](3.5_object_oriented_programming.ipynb)**
//
// ## Motivation
// You saw functions in many previous modules, but now it's time to make our own and use them effectively.
//
// ## Setup

// %%
val path = System.getProperty("user.dir") + "/source/load-ivy.sc"
interp.load.module(ammonite.ops.Path(java.nio.file.FileSystems.getDefault().getPath(path)))
// Out:
// path: String = "/home/hheile/Uni/ESD-Project/Code/chisel-bootcamp/source/load-ivy.sc"

// %% [markdown]
// This module uses the Chisel `FixedPoint` type, which currently resides in the experimental package.

// %%
import chisel3._
import chisel3.util._
import chisel3.tester._
import chisel3.tester.RawTester.test
import chisel3.experimental._
import chisel3.internal.firrtl.KnownBinaryPoint
// Out:
// import chisel3._
//
// import chisel3.util._
//
// import chisel3.tester._
//
// import chisel3.tester.RawTester.test
//
// import chisel3.experimental._
//
// import chisel3.internal.firrtl.KnownBinaryPoint

// %% [markdown]
// ---
// # Functional Programming in Scala
// Scala functions were introduced in Module 1, and you saw them being used a lot in the previous module. Here's a refresher on functions. Functions take any number of inputs and produce one output. Inputs are often called arguments to a function. To produce no output, return the `Unit` type.
//
// <span style="color:blue">**Example: Custom Functions**</span><br>
// Below are some examples of functions in Scala.

// %%
// No inputs or outputs (two versions).
def hello1(): Unit = println("Hello!")
def hello2 = println("Hello again!")

// Math operation: one input and one output.
def times2(x: Int): Int = 2 * x

// Inputs can have default values, and explicitly specifying the return type is optional.
// Note that we recommend specifying the return types to avoid surprises/bugs.
def timesN(x: Int, n: Int = 2) = n * x

// Call the functions listed above.
hello1()
hello2
times2(4)
timesN(4)         // no need to specify n to use the default value
timesN(4, 3)      // argument order is the same as the order where the function was defined
timesN(n=7, x=2)  // arguments may be reordered and assigned to explicitly
// Out:
// Hello!
// Hello again!
// defined function hello1
// defined function hello2
// defined function times2
// defined function timesN
// res2_6: Int = 8
// res2_7: Int = 8
// res2_8: Int = 12
// res2_9: Int = 14

// %% [markdown]
// ## Functions as Objects
// Functions in Scala are first-class objects. That means we can assign a function to a `val` and pass it to classes, objects, or other functions as an argument.
//
// <span style="color:blue">**Example: Function Objects**</span><br>
// Below are the same functions implemented as functions and as objects.

// %%
// These are normal functions.
def plus1funct(x: Int): Int = x + 1
def times2funct(x: Int): Int = x * 2

// These are functions as vals.
// The first one explicitly specifies the return type.
// This has the benefit that you can now pass these functions to other functions
val plus1val: Int => Int = x => x + 1       // function from Int => Int
val times2val = (x: Int) => x * 2

// Calling both looks the same.
plus1funct(4)
plus1val(4)
plus1funct(x=4)
// Out:
// defined function plus1funct
// defined function times2funct
// plus1val: Int => Int = ammonite.$sess.cmd3$Helper$$Lambda$2888/0x00007e81648ce538@61857299
// times2val: Int => Int = ammonite.$sess.cmd3$Helper$$Lambda$2889/0x00007e81648ce930@302d428
// res3_4: Int = 5
// res3_5: Int = 5
// res3_6: Int = 5

// %%
plus1val(x=4) // this doesn't work because the argument of plus1val was never named
// Out:
// cmd4.sc:1: not found: value x
// val res4 = plus1val(x=4) // this doesn't work because the argument of plus1val was never named
//                     ^Compilation Failed
// Compilation Failed

// %% [markdown]
// Why would you want to create a `val` instead of a `def`? With a `val`, you can now pass the function around to other functions, as shown below. You can even create your own functions that accept other functions as arguments. Formally, functions that take or produce functions are called *higher-order functions*. You saw them used in the last module, but now you'll make your own!
//
// <span style="color:blue">**Example: Higher-Order Functions**</span><br>
// Here we show `map` again, and we also create a new function, `opN`, that accepts a function, `op`, as an argument.

// %%
// create our functions that can be taken as paramters by other functions
val plus1 = (x: Int) => x + 1
val times2 = (x: Int) => x * 2

// create a list and pass the functions above to map to apply them to the lists
val myList = List(1, 2, 5, 9)
val myListPlus = myList.map(plus1)    // => output: List(2, 3,  6, 10)
val myListTimes = myList.map(times2)  // => output: List(2, 4, 10, 18)

// create a custom function, which performs an operation op on X N times, using recursion
def opN(x: Int, n: Int, op: Int => Int): Int = {
  if (n <= 0) { x }               // return the base value at the end of the recursion
  else { opN(op(x), n-1, op) }    // otherwise add another step of recursion
}

opN(7, 3, plus1)    // => (((7 + 1) + 1) + 1) = 10
opN(7, 3, times2)   // => (((7 * 2) * 2) * 2) = 56
// Out:
// plus1: Int => Int = ammonite.$sess.cmd4$Helper$$Lambda$2945/0x00007e81648d5e70@120bc4fd
// times2: Int => Int = ammonite.$sess.cmd4$Helper$$Lambda$2946/0x00007e81648d6268@574ec201
// myList: List[Int] = List(1, 2, 5, 9)
// myListPlus: List[Int] = List(2, 3, 6, 10)
// myListTimes: List[Int] = List(2, 4, 10, 18)
// defined function opN
// res4_6: Int = 10
// res4_7: Int = 56

// %% [markdown]
// <span style="color:blue">**Example: Functions vs. Objects**</span><br>
// A possibly confusing situation arises when using functions without arguments. Functions are evaluated every time they are called, while `val`s are evaluated at instantiation.

// %%
import scala.util.Random

// both x and y call the nextInt function, but x is evaluated immediately and y is a function and thus only evaluated when called
val x = Random.nextInt      // x is evaluated here and doesn't change from here on
def y = Random.nextInt

// x was previously evaluated, so it is a constant
println(s"x = $x")
println(s"x = $x")

// y is a function and gets reevaluated at each call, thus these produce different results
println(s"y = $y")          // y is evaluated here
println(s"y = $y")          // and here!
// Out:
// x = 1562249114
// x = 1562249114
// y = -1148359950
// y = -1041705871
// import scala.util.Random
//
// // both x and y call the nextInt function, but x is evaluated immediately and y is a function and thus only evaluated when called
//
// x: Int = 1562249114
// defined function y

// %% [markdown]
// ## Anonymous Functions
// As the name implies, anonymous functions are nameless. There's no need to create a `val` for a function if we'll only use it once.
//
// <span style="color:blue">**Example: Anonymous Functions**</span><br>
// The following example demonstrates this. They are often scoped (put in curly braces instead of parentheses).

// %%
val myList = List(5, 6, 7, 8)

// add one to every item in the list using an anonymous function
// arguments get passed to the underscore variable
// these all do the same thing
myList.map( (x:Int) => x + 1 )
myList.map(_ + 1)                             // this produces the SAME result as the call before, because myList is a constant!

// a common situation is to use case statements within an anonymous function
val myAnyList = List(1, 2, "3", 4L, myList)   // myList is still a constant and thus is inserted as it's inital value here as well!
myAnyList.map {
  case (_:Int|_:Long) => "Number"
  case _:String => "String"
  case _ => "error"
}
// Out:
// myList: List[Int] = List(5, 6, 7, 8)
// res6_1: List[Int] = List(6, 7, 8, 9)
// res6_2: List[Int] = List(6, 7, 8, 9)
// myAnyList: List[Any] = List(1, 2, "3", 4L, List(5, 6, 7, 8))
// res6_4: List[String] = List("Number", "Number", "String", "Number", "error")

// %% [markdown]
// <span style="color:red">**Exercise: Sequence Manipulation**</span><br>
// A common set of higher-order functions you'll use are `scanLeft`/`scanRight`, `reduceLeft`/`reduceRight`, and `foldLeft`/`foldRight`. It's important to understand how each one works and when to use them. The default directions for `scan`, `reduce`, and `fold` are left, though this is not guaranteed for all cases.

// %%
val exList = List(1, 5, 7, 100)

// write a custom function to add two numbers, then use reduce to find the sum of all values in exList
def add(a: Int, b: Int): Int = a + b
val sum = exList.reduce(add)            // you just hand over the function handle!

// find the sum of exList using an anonymous function (hint: you've seen this before!)
val anon_sum = exList.fold(0)(_ + _)        // equivalent to reduce

// find the moving average of exList from right to left using scan; make the result (ma2) a list of doubles
// scan works like fold but returns all intermediate results as well
def avg(a: Int, b: Double): Double = (a + b) / 2.0
val ma2 = exList.scanRight(0.0)(avg)              // you just hand over the function handle!
// Out:
// exList: List[Int] = List(1, 5, 7, 100)
// defined function add
// sum: Int = 113
// anon_sum: Int = 113
// defined function avg
// ma2: List[Double] = List(8.875, 16.75, 28.5, 50.0, 0.0)

// %%
assert(add(88, 88) == 176)
assert(sum == 113)

assert(anon_sum == 113)

assert(avg(100, 100.0) == 100.0)
assert(ma2 == List(8.875, 16.75, 28.5, 50.0, 0.0))
println("SUCCESS!!")
// Out:
// SUCCESS!!

// %% [markdown]
// <div id="container"><section id="accordion"><div>
// <input type="checkbox" id="check-1" />
// <label for="check-1"><strong>Solution</strong></label>
// <article>
// <pre style="background-color:#f7f7f7">
// def add(a: Int, b: Int): Int = a + b
// val sum = exList.reduce(add)
//
// val anon\_sum = exList.reduce(\_ + \_)
//
// def avg(a: Int, b: Double): Double = (a + b)/2.0
// val ma2 = exList.scanRight(0.0)(avg)
// </pre></article></div></section></div>

// %% [markdown]
// ---
// # Functional Programming in Chisel
// Let's look at some examples of how to use functional programming when creating hardware generators in Chisel.

// %% [markdown]
// <span style="color:blue">**Example: FIR Filter**</span><br>
// First, we'll revisit the FIR filter from previous examples. Instead of passing in the coefficients as parameters to the class or making them programmable, we'll pass a function to the FIR that defines how the window coefficients are calculated. This function will take the window length and bitwidth to produce a scaled list of coefficients. Here are two example windows. To avoid fractions, we'll scale the coefficients to be between the max and min integer values. For more on these windows, check out the [this Wikipedia page](https://en.wikipedia.org/wiki/Window_function).

// %%
// get some math functions
import scala.math.{abs, round, cos, Pi, pow}

// simple triangular window
val TriangularWindow: (Int, Int) => Seq[Int] = (length, bitwidth) => {
  val raw_coeffs = (0 until length).map( (x: Int) => 1-abs((x.toDouble-(length-1)/2.0)/((length-1)/2.0)) )
  val scaled_coeffs = raw_coeffs.map( (x: Double) => round(x * pow(2, bitwidth)).toInt)
  scaled_coeffs
}

// Hamming window
val HammingWindow: (Int, Int) => Seq[Int] = (length, bitwidth) => {
  val raw_coeffs = (0 until length).map( (x: Int) => 0.54 - 0.46*cos(2*Pi*x/(length-1)))
  val scaled_coeffs = raw_coeffs.map( (x: Double) => round(x * pow(2, bitwidth)).toInt)
  scaled_coeffs
}

// check it out! first argument is the window length, and second argument is the bitwidth
TriangularWindow(11, 16)
HammingWindow(11, 16)
// Out:
// import scala.math.{abs, round, cos, Pi, pow}
//
// // simple triangular window
//
// TriangularWindow: (Int, Int) => Seq[Int] = ammonite.$sess.cmd9$Helper$$Lambda$3207/0x00007e8164931e70@273ca60
// HammingWindow: (Int, Int) => Seq[Int] = ammonite.$sess.cmd9$Helper$$Lambda$3208/0x00007e8164932428@1658406f
// res9_3: Seq[Int] = Vector(
//   0,
//   13107,
//   26214,
//   39322,
//   52429,
//   65536,
//   52429,
//   39322,
//   26214,
//   13107,
//   0
// )
// res9_4: Seq[Int] = Vector(
//   5243,
//   11000,
//   26074,
//   44705,
//   59779,
//   65536,
//   59779,
//   44705,
//   26074,
//   11000,
//   5243
// )

// %% [markdown]
// Now we'll create a FIR filter that accepts a window function as the argument. This allows us to define new windows later on and retain the same FIR generator. It also allows us to independently size the FIR, knowing the window will be recalculated for different lengths or bitwidths. Since we are choosing the window at compile time, these coefficients are fixed.

// %%
// our FIR has parameterized window length, IO bitwidth, and windowing function
// this allows for easy implementations of different filtering coefficients via the given windowfunction
// the window is chosen at compile time and dynamically calculated on the given bitwidth and length => in the compiled module all these values are fixed
class MyFir(length: Int, bitwidth: Int, window: (Int, Int) => Seq[Int]) extends Module {
  val io = IO(new Bundle {
    val in = Input(UInt(bitwidth.W))
    val out = Output(UInt((bitwidth*2+length-1).W)) // expect bit growth, conservative but lazy
  })

  // calculate the coefficients using the provided window function, mapping to UInts
  val coeffs = window(length, bitwidth).map(_.U)
  
  // create an array holding the output of the delays
  // note: we avoid using a Vec here since we don't need dynamic indexing
  val delays = Seq.fill(length)(Wire(UInt(bitwidth.W))).scan(io.in)( (prev: UInt, next: UInt) => {
    next := RegNext(prev)
    next
  })
  
  // multiply, putting result in "mults"
  val mults = delays.zip(coeffs).map{ case(delay: UInt, coeff: UInt) => delay * coeff }
  
  // add up multiplier outputs with bit growth
  val result = mults.reduce(_+&_)

  // connect output
  io.out := result
}

visualize(() => new MyFir(7, 12, TriangularWindow))
// Out:
// <div width="100%" height="100%" overflow="scroll"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <?xml-stylesheet href="styles.css" type="text/css"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.43.0 (0)
//  -->
// <!-- Title: MyFir Pages: 1 -->
// <svg width="1995pt" height="325pt"
//  viewBox="0.00 0.00 1995.00 325.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 321)">
// <title>MyFir</title>
// <polygon fill="white" stroke="transparent" points="-4,4 -4,-321 1991,-321 1991,4 -4,4"/>
// <g id="clust1" class="cluster">
// <title>cluster_MyFir</title>
// <polygon fill="#fff8dc" stroke="black" points="8,-8 8,-309 1979,-309 1979,-8 8,-8"/>
// <text text-anchor="middle" x="993.5" y="-293.8" font-family="Times,serif" font-size="14.00">MyFir</text>
// </g>
// <!-- cluster_MyFir_clock -->
// <g id="node1" class="node">
// <title>cluster_MyFir_clock</title>
// <polygon fill="#cccccc" stroke="black" points="70,-278 16,-278 16,-242 70,-242 70,-278"/>
// <text text-anchor="middle" x="43" y="-256.3" font-family="Times,serif" font-size="14.00">clock</text>
// </g>
// <!-- cluster_MyFir_reset -->
// <g id="node2" class="node">
// <title>cluster_MyFir_reset</title>
// <polygon fill="#cccccc" stroke="black" points="70,-224 16,-224 16,-188 70,-188 70,-224"/>
// <text text-anchor="middle" x="43" y="-202.3" font-family="Times,serif" font-size="14.00">reset</text>
// </g>
// <!-- cluster_MyFir_io_in -->
// <g id="node3" class="node">
// <title>cluster_MyFir_io_in</title>
// <polygon fill="#cccccc" stroke="black" points="70,-170 16,-170 16,-134 70,-134 70,-170"/>
// <text text-anchor="middle" x="43" y="-148.3" font-family="Times,serif" font-size="14.00">io_in</text>
// </g>
// <!-- struct_cluster_MyFir_REG -->
// <g id="node5" class="node">
// <title>struct_cluster_MyFir_REG</title>
// <polygon fill="#ffe4b5" stroke="transparent" points="116,-140.5 116,-165.5 205,-165.5 205,-140.5 116,-140.5"/>
// <polygon fill="none" stroke="black" points="116.5,-140 116.5,-165 139.5,-165 139.5,-140 116.5,-140"/>
// <text text-anchor="start" x="121.5" y="-148.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="139.5,-140 139.5,-165 182.5,-165 182.5,-140 139.5,-140"/>
// <text text-anchor="start" x="144.5" y="-148.8" font-family="Times,serif" font-size="14.00">REG</text>
// <polygon fill="none" stroke="black" points="182.5,-140 182.5,-165 205.5,-165 205.5,-140 182.5,-140"/>
// <text text-anchor="start" x="187.5" y="-148.8" font-family="Times,serif" font-size="14.00">●</text>
// </g>
// <!-- cluster_MyFir_io_in&#45;&gt;struct_cluster_MyFir_REG -->
// <g id="edge37" class="edge">
// <title>cluster_MyFir_io_in&#45;&gt;struct_cluster_MyFir_REG:in</title>
// <path fill="none" stroke="black" d="M70.15,-152C80.72,-152 93.29,-152 105.44,-152"/>
// <polygon fill="black" stroke="black" points="105.5,-155.5 115.5,-152 105.5,-148.5 105.5,-155.5"/>
// </g>
// <!-- op_mul_1 -->
// <g id="node12" class="node">
// <title>op_mul_1</title>
// <polygon fill="#d8bfd8" stroke="transparent" points="114,-208 114,-258 207,-258 207,-208 114,-208"/>
// <polygon fill="none" stroke="black" points="114.5,-233 114.5,-258 137.5,-258 137.5,-233 114.5,-233"/>
// <text text-anchor="start" x="119.5" y="-241.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="137.5,-208 137.5,-258 184.5,-258 184.5,-208 137.5,-208"/>
// <text text-anchor="start" x="142.5" y="-229.3" font-family="Times,serif" font-size="14.00"> mul </text>
// <polygon fill="none" stroke="black" points="184.5,-208 184.5,-258 207.5,-258 207.5,-208 184.5,-208"/>
// <text text-anchor="start" x="189.5" y="-229.3" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="114.5,-208 114.5,-233 137.5,-233 137.5,-208 114.5,-208"/>
// <text text-anchor="start" x="121" y="-216.8" font-family="Times,serif" font-size="14.00">0</text>
// </g>
// <!-- cluster_MyFir_io_in&#45;&gt;op_mul_1 -->
// <g id="edge21" class="edge">
// <title>cluster_MyFir_io_in&#45;&gt;op_mul_1:in1</title>
// <path fill="none" stroke="black" d="M62.39,-170.17C65.03,-173.04 67.65,-176.04 70,-179 89.67,-203.76 80.64,-237.56 103.52,-244.66"/>
// <polygon fill="black" stroke="black" points="103.12,-248.14 113.5,-246 104.05,-241.2 103.12,-248.14"/>
// </g>
// <!-- cluster_MyFir_io_out -->
// <g id="node4" class="node">
// <title>cluster_MyFir_io_out</title>
// <polygon fill="#e0ffff" stroke="black" points="1971,-111 1912,-111 1912,-75 1971,-75 1971,-111"/>
// <text text-anchor="middle" x="1941.5" y="-89.3" font-family="Times,serif" font-size="14.00">io_out</text>
// </g>
// <!-- struct_cluster_MyFir_REG_1 -->
// <g id="node6" class="node">
// <title>struct_cluster_MyFir_REG_1</title>
// <polygon fill="#ffe4b5" stroke="transparent" points="265,-116.5 265,-141.5 370,-141.5 370,-116.5 265,-116.5"/>
// <polygon fill="none" stroke="black" points="265.5,-116 265.5,-141 288.5,-141 288.5,-116 265.5,-116"/>
// <text text-anchor="start" x="270.5" y="-124.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="288.5,-116 288.5,-141 347.5,-141 347.5,-116 288.5,-116"/>
// <text text-anchor="start" x="293.5" y="-124.8" font-family="Times,serif" font-size="14.00">REG_1</text>
// <polygon fill="none" stroke="black" points="347.5,-116 347.5,-141 370.5,-141 370.5,-116 347.5,-116"/>
// <text text-anchor="start" x="352.5" y="-124.8" font-family="Times,serif" font-size="14.00">●</text>
// </g>
// <!-- struct_cluster_MyFir_REG&#45;&gt;struct_cluster_MyFir_REG_1 -->
// <g id="edge10" class="edge">
// <title>struct_cluster_MyFir_REG:out&#45;&gt;struct_cluster_MyFir_REG_1:in</title>
// <path fill="none" stroke="black" d="M206.5,-152C230.58,-152 235.52,-134.11 254.37,-129.22"/>
// <polygon fill="black" stroke="black" points="254.99,-132.67 264.5,-128 254.15,-125.72 254.99,-132.67"/>
// </g>
// <!-- op_mul_2 -->
// <g id="node14" class="node">
// <title>op_mul_2</title>
// <polygon fill="#d8bfd8" stroke="transparent" points="259,-169 259,-219 376,-219 376,-169 259,-169"/>
// <polygon fill="none" stroke="black" points="259.5,-194 259.5,-219 306.5,-219 306.5,-194 259.5,-194"/>
// <text text-anchor="start" x="276.5" y="-202.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="306.5,-169 306.5,-219 353.5,-219 353.5,-169 306.5,-169"/>
// <text text-anchor="start" x="311.5" y="-190.3" font-family="Times,serif" font-size="14.00"> mul </text>
// <polygon fill="none" stroke="black" points="353.5,-169 353.5,-219 376.5,-219 376.5,-169 353.5,-169"/>
// <text text-anchor="start" x="358.5" y="-190.3" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="259.5,-169 259.5,-194 306.5,-194 306.5,-169 259.5,-169"/>
// <text text-anchor="start" x="264.5" y="-177.8" font-family="Times,serif" font-size="14.00">1365</text>
// </g>
// <!-- struct_cluster_MyFir_REG&#45;&gt;op_mul_2 -->
// <g id="edge34" class="edge">
// <title>struct_cluster_MyFir_REG:out&#45;&gt;op_mul_2:in1</title>
// <path fill="none" stroke="black" d="M206.5,-152C236.2,-152 227.77,-194.86 248.53,-204.91"/>
// <polygon fill="black" stroke="black" points="247.99,-208.37 258.5,-207 249.43,-201.52 247.99,-208.37"/>
// </g>
// <!-- struct_cluster_MyFir_REG_2 -->
// <g id="node7" class="node">
// <title>struct_cluster_MyFir_REG_2</title>
// <polygon fill="#ffe4b5" stroke="transparent" points="434,-63.5 434,-88.5 539,-88.5 539,-63.5 434,-63.5"/>
// <polygon fill="none" stroke="black" points="434.5,-63 434.5,-88 457.5,-88 457.5,-63 434.5,-63"/>
// <text text-anchor="start" x="439.5" y="-71.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="457.5,-63 457.5,-88 516.5,-88 516.5,-63 457.5,-63"/>
// <text text-anchor="start" x="462.5" y="-71.8" font-family="Times,serif" font-size="14.00">REG_2</text>
// <polygon fill="none" stroke="black" points="516.5,-63 516.5,-88 539.5,-88 539.5,-63 516.5,-63"/>
// <text text-anchor="start" x="521.5" y="-71.8" font-family="Times,serif" font-size="14.00">●</text>
// </g
// defined class MyFir

// %%
visualize(() => new MyFir(7, 12, HammingWindow))
// Out:
// <div width="100%" height="100%" overflow="scroll"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <?xml-stylesheet href="styles.css" type="text/css"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.43.0 (0)
//  -->
// <!-- Title: MyFir Pages: 1 -->
// <svg width="2025pt" height="325pt"
//  viewBox="0.00 0.00 2025.00 325.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 321)">
// <title>MyFir</title>
// <polygon fill="white" stroke="transparent" points="-4,4 -4,-321 2021,-321 2021,4 -4,4"/>
// <g id="clust1" class="cluster">
// <title>cluster_MyFir</title>
// <polygon fill="#fff8dc" stroke="black" points="8,-8 8,-309 2009,-309 2009,-8 8,-8"/>
// <text text-anchor="middle" x="1008.5" y="-293.8" font-family="Times,serif" font-size="14.00">MyFir</text>
// </g>
// <!-- cluster_MyFir_clock -->
// <g id="node1" class="node">
// <title>cluster_MyFir_clock</title>
// <polygon fill="#cccccc" stroke="black" points="70,-278 16,-278 16,-242 70,-242 70,-278"/>
// <text text-anchor="middle" x="43" y="-256.3" font-family="Times,serif" font-size="14.00">clock</text>
// </g>
// <!-- cluster_MyFir_reset -->
// <g id="node2" class="node">
// <title>cluster_MyFir_reset</title>
// <polygon fill="#cccccc" stroke="black" points="70,-224 16,-224 16,-188 70,-188 70,-224"/>
// <text text-anchor="middle" x="43" y="-202.3" font-family="Times,serif" font-size="14.00">reset</text>
// </g>
// <!-- cluster_MyFir_io_in -->
// <g id="node3" class="node">
// <title>cluster_MyFir_io_in</title>
// <polygon fill="#cccccc" stroke="black" points="70,-170 16,-170 16,-134 70,-134 70,-170"/>
// <text text-anchor="middle" x="43" y="-148.3" font-family="Times,serif" font-size="14.00">io_in</text>
// </g>
// <!-- struct_cluster_MyFir_REG -->
// <g id="node5" class="node">
// <title>struct_cluster_MyFir_REG</title>
// <polygon fill="#ffe4b5" stroke="transparent" points="123.5,-140.5 123.5,-165.5 212.5,-165.5 212.5,-140.5 123.5,-140.5"/>
// <polygon fill="none" stroke="black" points="124,-140 124,-165 147,-165 147,-140 124,-140"/>
// <text text-anchor="start" x="129" y="-148.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="147,-140 147,-165 190,-165 190,-140 147,-140"/>
// <text text-anchor="start" x="152" y="-148.8" font-family="Times,serif" font-size="14.00">REG</text>
// <polygon fill="none" stroke="black" points="190,-140 190,-165 213,-165 213,-140 190,-140"/>
// <text text-anchor="start" x="195" y="-148.8" font-family="Times,serif" font-size="14.00">●</text>
// </g>
// <!-- cluster_MyFir_io_in&#45;&gt;struct_cluster_MyFir_REG -->
// <g id="edge36" class="edge">
// <title>cluster_MyFir_io_in&#45;&gt;struct_cluster_MyFir_REG:in</title>
// <path fill="none" stroke="black" d="M70.33,-152C82.81,-152 98.19,-152 112.94,-152"/>
// <polygon fill="black" stroke="black" points="113,-155.5 123,-152 113,-148.5 113,-155.5"/>
// </g>
// <!-- op_mul_19 -->
// <g id="node12" class="node">
// <title>op_mul_19</title>
// <polygon fill="#d8bfd8" stroke="transparent" points="114,-208 114,-258 222,-258 222,-208 114,-208"/>
// <polygon fill="none" stroke="black" points="114,-233 114,-258 152,-258 152,-233 114,-233"/>
// <text text-anchor="start" x="126.5" y="-241.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="152,-208 152,-258 199,-258 199,-208 152,-208"/>
// <text text-anchor="start" x="157" y="-229.3" font-family="Times,serif" font-size="14.00"> mul </text>
// <polygon fill="none" stroke="black" points="199,-208 199,-258 222,-258 222,-208 199,-208"/>
// <text text-anchor="start" x="204" y="-229.3" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="114,-208 114,-233 152,-233 152,-208 114,-208"/>
// <text text-anchor="start" x="119" y="-216.8" font-family="Times,serif" font-size="14.00">328</text>
// </g>
// <!-- cluster_MyFir_io_in&#45;&gt;op_mul_19 -->
// <g id="edge21" class="edge">
// <title>cluster_MyFir_io_in&#45;&gt;op_mul_19:in1</title>
// <path fill="none" stroke="black" d="M62.4,-170.15C65.05,-173.03 67.66,-176.04 70,-179 89.53,-203.73 80.31,-237.55 103.06,-244.66"/>
// <polygon fill="black" stroke="black" points="102.62,-248.13 113,-246 103.56,-241.19 102.62,-248.13"/>
// </g>
// <!-- cluster_MyFir_io_out -->
// <g id="node4" class="node">
// <title>cluster_MyFir_io_out</title>
// <polygon fill="#e0ffff" stroke="black" points="2001,-111 1942,-111 1942,-75 2001,-75 2001,-111"/>
// <text text-anchor="middle" x="1971.5" y="-89.3" font-family="Times,serif" font-size="14.00">io_out</text>
// </g>
// <!-- struct_cluster_MyFir_REG_1 -->
// <g id="node6" class="node">
// <title>struct_cluster_MyFir_REG_1</title>
// <polygon fill="#ffe4b5" stroke="transparent" points="280,-116.5 280,-141.5 385,-141.5 385,-116.5 280,-116.5"/>
// <polygon fill="none" stroke="black" points="280.5,-116 280.5,-141 303.5,-141 303.5,-116 280.5,-116"/>
// <text text-anchor="start" x="285.5" y="-124.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="303.5,-116 303.5,-141 362.5,-141 362.5,-116 303.5,-116"/>
// <text text-anchor="start" x="308.5" y="-124.8" font-family="Times,serif" font-size="14.00">REG_1</text>
// <polygon fill="none" stroke="black" points="362.5,-116 362.5,-141 385.5,-141 385.5,-116 362.5,-116"/>
// <text text-anchor="start" x="367.5" y="-124.8" font-family="Times,serif" font-size="14.00">●</text>
// </g>
// <!-- struct_cluster_MyFir_REG&#45;&gt;struct_cluster_MyFir_REG_1 -->
// <g id="edge9" class="edge">
// <title>struct_cluster_MyFir_REG:out&#45;&gt;struct_cluster_MyFir_REG_1:in</title>
// <path fill="none" stroke="black" d="M214,-152C241.25,-152 247.25,-133.46 269.35,-128.97"/>
// <polygon fill="black" stroke="black" points="269.88,-132.44 279.5,-128 269.21,-125.47 269.88,-132.44"/>
// </g>
// <!-- op_mul_20 -->
// <g id="node14" class="node">
// <title>op_mul_20</title>
// <polygon fill="#d8bfd8" stroke="transparent" points="274,-169 274,-219 391,-219 391,-169 274,-169"/>
// <polygon fill="none" stroke="black" points="274.5,-194 274.5,-219 321.5,-219 321.5,-194 274.5,-194"/>
// <text text-anchor="start" x="291.5" y="-202.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="321.5,-169 321.5,-219 368.5,-219 368.5,-169 321.5,-169"/>
// <text text-anchor="start" x="326.5" y="-190.3" font-family="Times,serif" font-size="14.00"> mul </text>
// <polygon fill="none" stroke="black" points="368.5,-169 368.5,-219 391.5,-219 391.5,-169 368.5,-169"/>
// <text text-anchor="start" x="373.5" y="-190.3" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="274.5,-169 274.5,-194 321.5,-194 321.5,-169 274.5,-169"/>
// <text text-anchor="start" x="279.5" y="-177.8" font-family="Times,serif" font-size="14.00">1270</text>
// </g>
// <!-- struct_cluster_MyFir_REG&#45;&gt;op_mul_20 -->
// <g id="edge13" class="edge">
// <title>struct_cluster_MyFir_REG:out&#45;&gt;op_mul_20:in1</title>
// <path fill="none" stroke="black" d="M214,-152C246.21,-152 239.59,-196.01 263.61,-205.29"/>
// <polygon fill="black" stroke="black" points="263.05,-208.75 273.5,-207 264.24,-201.85 263.05,-208.75"/>
// </g>
// <!-- struct_cluster_MyFir_REG_2 -->
// <g id="node7" class="node">
// <title>struct_cluster_MyFir_REG_2</title>
// <polygon fill="#ffe4b5" stroke="transparent" points="449,-63.5 449,-88.5 554,-88.5 554,-63.5 449,-63.5"/>
// <polygon fill="none" stroke="black" points="449.5,-63 449.5,-88 472.5,-88 472.5,-63 449.5,-63"/>
// <text text-anchor="start" x="454.5" y="-71.8" font-family="Times,serif" font-size="14.00">●</text>
// <polygon fill="none" stroke="black" points="472.5,-63 472.5,-88 531.5,-88 531.5,-63 472.5,-63"/>
// <text text-anchor="start" x="477.5" y="-71.8" font-family="Times,serif" font-size="14.00">REG_2</text>
// <polygon fill="none" stroke="black" points="531.5,-63 531.5,-88 554.5,-88 554.5,-63 531.5,-63"/>
// <text text-anchor="start" x="536.5" y="-71.8" font-family="Times,serif" font-size="14.00">●</text>
// </g>
// <!-- struct_cluster_MyFir_REG_1&#45;&gt;struct_cluster_MyFir_REG_2 -->

// %% [markdown]
// Those last three lines could be easily combined into one. Also notice how we've handled bitwidth growth conservatively to avoid loss.
//
// <span style="color:blue">**Example: FIR Filter Tester**</span><br>
// Let's test our FIR! Previously, we provided a custom golden model. This time we'll use Breeze, a Scala library of useful linear algebra and signal processing functions, as a golden model for our FIR filter. The code below compares the Chisel output with the golden model output, and any errors cause the tester to fail.
//
// Try uncommenting the print statment at the end just after the expect call. Also try changing the window from triangular to Hamming.

// %%
// math imports
import scala.math.{pow, sin, Pi}
import breeze.signal.{filter, OptOverhang}
import breeze.signal.support.{CanFilter, FIRKernel1D}
import breeze.linalg.DenseVector

// test parameters
val length = 7
val bitwidth = 12 // must be less than 15, otherwise Int can't represent the data, would need BigInt
val window = TriangularWindow

// test our FIR
test(new MyFir(length, bitwidth, window)) { c =>
    
    // test data
    val n = 100 // input length
    val sine_freq = 10
    val samp_freq = 100

    // sample data, scale to between 0 and 2^bitwidth
    val max_value = pow(2, bitwidth)-1
    val sine = (0 until n).map(i => (max_value/2 + max_value/2*sin(2*Pi*sine_freq/samp_freq*i)).toInt)
    println(s"input = ${sine.toArray.deep.mkString(", ")}")

    // coefficients
    val coeffs = window(length, bitwidth)
    println(s"coeffs = ${coeffs.toArray.deep.mkString(", ")}")

    // use breeze filter as golden model; need to reverse coefficients
    val expected = filter(
        DenseVector(sine.toArray),
        FIRKernel1D(DenseVector(coeffs.reverse.toArray), 1.0, ""),
        OptOverhang.None
    )
    expected.toArray // seems to be necessary
    //println(s"exp_out = ${expected.toArray.deep.mkString(", ")}") // this seems to be necessary

    // push data through our FIR and check the result
    c.reset.poke(true.B)
    c.clock.step(5)
    c.reset.poke(false.B)
    for (i <- 0 until n) {
        c.io.in.poke(sine(i).U)
        if (i >= length-1) { // wait for all registers to be initialized since we didn't zero-pad the data
            val expectValue = expected(i-length+1)
            //println(s"expected value is $expectValue")
            c.io.out.expect(expected(i-length+1).U)
            println(s"cycle $i, got ${c.io.out.peek()}, expect ${expected(i-length+1)}")
        }
        c.clock.step(1)
    }
}
println("SUCCESS!!")
// Out:
// input = 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844
// coeffs = 0, 1365, 2731, 4096, 2731, 1365, 0
// cycle 6, got UInt<30>(43373193), expect 43373193
// cycle 7, got UInt<30>(36413841), expect 36413841
// cycle 8, got UInt<30>(25153536), expect 25153536
// cycle 9, got UInt<30>(13893231), expect 13893231
// cycle 10, got UInt<30>(6933879), expect 6933879
// cycle 11, got UInt<30>(6933879), expect 6933879
// cycle 12, got UInt<30>(13893231), expect 13893231
// cycle 13, got UInt<30>(25153536), expect 25153536
// cycle 14, got UInt<30>(36413841), expect 36413841
// cycle 15, got UInt<30>(43373193), expect 43373193
// cycle 16, got UInt<30>(43373193), expect 43373193
// cycle 17, got UInt<30>(36413841), expect 36413841
// cycle 18, got UInt<30>(25153536), expect 25153536
// cycle 19, got UInt<30>(13893231), expect 13893231
// cycle 20, got UInt<30>(6933879), expect 6933879
// cycle 21, got UInt<30>(6933879), expect 6933879
// cycle 22, got UInt<30>(13893231), expect 13893231
// cycle 23, got UInt<30>(25153536), expect 25153536
// cycle 24, got UInt<30>(36413841), expect 36413841
// cycle 25, got UInt<30>(43373193), expect 43373193
// cycle 26, got UInt<30>(43373193), expect 43373193
// cycle 27, got UInt<30>(36413841), expect 36413841
// cycle 28, got UInt<30>(25153536), expect 25153536
// cycle 29, got UInt<30>(13893231), expect 13893231
// cycle 30, got UInt<30>(6933879), expect 6933879
// cycle 31, got UInt<30>(6933879), expect 6933879
// cycle 32, got UInt<30>(13893231), expect 13893231
// cycle 33, got UInt<30>(25153536), expect 25153536
// cycle 34, got UInt<30>(36413841), expect 36413841
// cycle 35, got UInt<30>(43373193), expect 43373193
// cycle 36, got UInt<30>(43373193), expect 43373193
// cycle 37, got UInt<30>(36413841), expect 36413841
// cycle 38, got UInt<30>(25153536), expect 25153536
// cycle 39, got UInt<30>(13893231), expect 13893231
// cycle 40, got UInt<30>(6933879), expect 6933879
// cycle 41, got UInt<30>(6933879), expect 6933879
// cycle 42, got UInt<30>(13893231), expect 13893231
// cycle 43, got UInt<30>(25153536), expect 25153536
// cycle 44, got UInt<30>(36413841), expect 36413841
// cycle 45, got UInt<30>(43373193), expect 43373193
// cycle 46, got UInt<30>(43373193), expect 43373193
// cycle 47, got UInt<30>(36413841), expect 36413841
// cycle 48, got UInt<30>(25153536), expect 25153536
// cycle 49, got UInt<30>(13893231), expect 13893231
// cycle 50, got UInt<30>(6933879), expect 6933879
// cycle 51, got UInt<30>(6933879), expect 6933879
// cycle 52, got UInt<30>(13893231), expect 13893231
// cycle 53, got UInt<30>(25153536), expect 25153536
// cycle 54, got UInt<30>(36413841), expect 36413841
// cycle 55, got UInt<30>(43373193), expect 43373193
// cycle 56, got UInt<30>(43373193), expect 43373193
// cycle 57, got UInt<30>(36413841), expect 36413841
// cycle 58, got UInt<30>(25153536), expect 25153536
// cycle 59, got UInt<30>(13893231), expect 13893231
// cycle 60, got UInt<30>(6933879), expect 6933879
// cycle 61, got UInt<30>(6933879), expect 6933879
// cycle 62, got UInt<30>(13893231), expect 13893231
// cycle 63, got UInt<30>(25153536), expect 25153536
// cycle 64, got UInt<30>(36413841), expect 36413841
// cycle 65, got UInt<30>(43373193), expect 43373193
// cycle 66, got UInt<30>(43373193), expect 43373193
// cycle 67, got UInt<30>(36413841), expect 36413841
// cycle 68, got UInt<30>(25153536), expect 25153536
// cycle 69, got UInt<30>(13893231), expect 13893231
// cycle 70, got UInt<30>(6933879), expect 6933879
// cycle 71, got UInt<30>(6933879), expect 6933879
// cycle 72, got UInt<30>(13893231), expect 13893231
// cycle 73, got UInt<30>(25153536), expect 25153536
// cycle 74, got UInt<30>(36413841), expect 36413841
// cycle 75, got UInt<30>(43373193), expect 43373193
// cycle 76, got UInt<30>(43373193), expect 43373193
// cycle 77, got UInt<30>(36413841), expect 36413841
// cycle 78, got UInt<30>(25153536), expect 25153536
// cycle 79, got UInt<30>(13893231), expect 13893231
// cycle 80, got UInt<30>(6933879), expect 6933879
// cycle 81, got UInt<30>(6933879), expect 6933879
// cycle 82, got UInt<30>(13893231), expect 13893231
// cycle 83, got UInt<30>(25153536), expect 25153536
// cycle 84, got UInt<30>(36413841), expect 36413841
// cycle 85, got UInt<30>(43373193), expect 43373193
// cycle 86, got UInt<30>(43373193), expect 43373193
// cycle 87, got UInt<30>(36413841), expect 36413841
// cycle 88, got UInt<30>(25153536), expect 25153536
// cycle 89, got UInt<30>(13893231), expect 13893231
// cycle 90, got UInt<30>(6933879), expect 6933879
// cycle 91, got UInt<30>(6933879), expect 6933879
// cycle 92, got UInt<30>(13893231), expect 13893231
// cycle 93, got UInt<30>(25153536), expect 25153536
// cycle 94, got UInt<30>(36413841), expect 36413841
// cycle 95, got UInt<30>(43373193), expect 43373193
// cycle 96, got UInt<30>(43373193), expect 43373193
// cycle 97, got UInt<30>(36413841), expect 36413841
// cycle 98, got UInt<30>(25153536), expect 25153536
// cycle 99, got UInt<30>(13893231), expect 13893231
// test MyFir Success: 0 tests passed in 107 cycles in 0.304220 seconds 351.72 Hz
// SUCCESS!!
// import scala.math.{pow, sin, Pi}
//
// import breeze.signal.{filter, OptOverhang}
//
// import breeze.signal.support.{CanFilter, FIRKernel1D}
//
// import breeze.linalg.DenseVector
//
// // test parameters
//
// length: Int = 7
// bitwidth: Int = 12
// window: (Int, Int) => Seq[Int] = ammonite.$sess.cmd9$Helper$$Lambda$3207/0x00007e8164931e70@273ca60

// %%
val window = HammingWindow

// test our FIR
test(new MyFir(length, bitwidth, window)) { c =>
    
    // test data
    val n = 100 // input length
    val sine_freq = 10
    val samp_freq = 100

    // sample data, scale to between 0 and 2^bitwidth
    val max_value = pow(2, bitwidth)-1
    val sine = (0 until n).map(i => (max_value/2 + max_value/2*sin(2*Pi*sine_freq/samp_freq*i)).toInt)
    println(s"input = ${sine.toArray.deep.mkString(", ")}")

    // coefficients
    val coeffs = window(length, bitwidth)
    println(s"coeffs = ${coeffs.toArray.deep.mkString(", ")}")

    // use breeze filter as golden model; need to reverse coefficients
    val expected = filter(
        DenseVector(sine.toArray),
        FIRKernel1D(DenseVector(coeffs.reverse.toArray), 1.0, ""),
        OptOverhang.None
    )
    expected.toArray // seems to be necessary
    // println(s"exp_out = ${expected.toArray.deep.mkString(", ")}") // this seems to be necessary

    // push data through our FIR and check the result
    c.reset.poke(true.B)
    c.clock.step(5)
    c.reset.poke(false.B)
    for (i <- 0 until n) {
        c.io.in.poke(sine(i).U)
        if (i >= length-1) { // wait for all registers to be initialized since we didn't zero-pad the data
            val expectValue = expected(i-length+1)
            //println(s"expected value is $expectValue")
            c.io.out.expect(expected(i-length+1).U)
            println(s"cycle $i, got ${c.io.out.peek()}, expect ${expected(i-length+1)}")
        }
        c.clock.step(1)
    }
}
println("SUCCESS!!")
// Out:
// input = 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844, 2047, 3250, 3994, 3994, 3250, 2047, 844, 100, 100, 844
// coeffs = 328, 1270, 3154, 4096, 3154, 1270, 328
// cycle 6, got UInt<30>(46882438), expect 46882438
// cycle 7, got UInt<30>(39608374), expect 39608374
// cycle 8, got UInt<30>(27839200), expect 27839200
// cycle 9, got UInt<30>(16070026), expect 16070026
// cycle 10, got UInt<30>(8795962), expect 8795962
// cycle 11, got UInt<30>(8795962), expect 8795962
// cycle 12, got UInt<30>(16070026), expect 16070026
// cycle 13, got UInt<30>(27839200), expect 27839200
// cycle 14, got UInt<30>(39608374), expect 39608374
// cycle 15, got UInt<30>(46882438), expect 46882438
// cycle 16, got UInt<30>(46882438), expect 46882438
// cycle 17, got UInt<30>(39608374), expect 39608374
// cycle 18, got UInt<30>(27839200), expect 27839200
// cycle 19, got UInt<30>(16070026), expect 16070026
// cycle 20, got UInt<30>(8795962), expect 8795962
// cycle 21, got UInt<30>(8795962), expect 8795962
// cycle 22, got UInt<30>(16070026), expect 16070026
// cycle 23, got UInt<30>(27839200), expect 27839200
// cycle 24, got UInt<30>(39608374), expect 39608374
// cycle 25, got UInt<30>(46882438), expect 46882438
// cycle 26, got UInt<30>(46882438), expect 46882438
// cycle 27, got UInt<30>(39608374), expect 39608374
// cycle 28, got UInt<30>(27839200), expect 27839200
// cycle 29, got UInt<30>(16070026), expect 16070026
// cycle 30, got UInt<30>(8795962), expect 8795962
// cycle 31, got UInt<30>(8795962), expect 8795962
// cycle 32, got UInt<30>(16070026), expect 16070026
// cycle 33, got UInt<30>(27839200), expect 27839200
// cycle 34, got UInt<30>(39608374), expect 39608374
// cycle 35, got UInt<30>(46882438), expect 46882438
// cycle 36, got UInt<30>(46882438), expect 46882438
// cycle 37, got UInt<30>(39608374), expect 39608374
// cycle 38, got UInt<30>(27839200), expect 27839200
// cycle 39, got UInt<30>(16070026), expect 16070026
// cycle 40, got UInt<30>(8795962), expect 8795962
// cycle 41, got UInt<30>(8795962), expect 8795962
// cycle 42, got UInt<30>(16070026), expect 16070026
// cycle 43, got UInt<30>(27839200), expect 27839200
// cycle 44, got UInt<30>(39608374), expect 39608374
// cycle 45, got UInt<30>(46882438), expect 46882438
// cycle 46, got UInt<30>(46882438), expect 46882438
// cycle 47, got UInt<30>(39608374), expect 39608374
// cycle 48, got UInt<30>(27839200), expect 27839200
// cycle 49, got UInt<30>(16070026), expect 16070026
// cycle 50, got UInt<30>(8795962), expect 8795962
// cycle 51, got UInt<30>(8795962), expect 8795962
// cycle 52, got UInt<30>(16070026), expect 16070026
// cycle 53, got UInt<30>(27839200), expect 27839200
// cycle 54, got UInt<30>(39608374), expect 39608374
// cycle 55, got UInt<30>(46882438), expect 46882438
// cycle 56, got UInt<30>(46882438), expect 46882438
// cycle 57, got UInt<30>(39608374), expect 39608374
// cycle 58, got UInt<30>(27839200), expect 27839200
// cycle 59, got UInt<30>(16070026), expect 16070026
// cycle 60, got UInt<30>(8795962), expect 8795962
// cycle 61, got UInt<30>(8795962), expect 8795962
// cycle 62, got UInt<30>(16070026), expect 16070026
// cycle 63, got UInt<30>(27839200), expect 27839200
// cycle 64, got UInt<30>(39608374), expect 39608374
// cycle 65, got UInt<30>(46882438), expect 46882438
// cycle 66, got UInt<30>(46882438), expect 46882438
// cycle 67, got UInt<30>(39608374), expect 39608374
// cycle 68, got UInt<30>(27839200), expect 27839200
// cycle 69, got UInt<30>(16070026), expect 16070026
// cycle 70, got UInt<30>(8795962), expect 8795962
// cycle 71, got UInt<30>(8795962), expect 8795962
// cycle 72, got UInt<30>(16070026), expect 16070026
// cycle 73, got UInt<30>(27839200), expect 27839200
// cycle 74, got UInt<30>(39608374), expect 39608374
// cycle 75, got UInt<30>(46882438), expect 46882438
// cycle 76, got UInt<30>(46882438), expect 46882438
// cycle 77, got UInt<30>(39608374), expect 39608374
// cycle 78, got UInt<30>(27839200), expect 27839200
// cycle 79, got UInt<30>(16070026), expect 16070026
// cycle 80, got UInt<30>(8795962), expect 8795962
// cycle 81, got UInt<30>(8795962), expect 8795962
// cycle 82, got UInt<30>(16070026), expect 16070026
// cycle 83, got UInt<30>(27839200), expect 27839200
// cycle 84, got UInt<30>(39608374), expect 39608374
// cycle 85, got UInt<30>(46882438), expect 46882438
// cycle 86, got UInt<30>(46882438), expect 46882438
// cycle 87, got UInt<30>(39608374), expect 39608374
// cycle 88, got UInt<30>(27839200), expect 27839200
// cycle 89, got UInt<30>(16070026), expect 16070026
// cycle 90, got UInt<30>(8795962), expect 8795962
// cycle 91, got UInt<30>(8795962), expect 8795962
// cycle 92, got UInt<30>(16070026), expect 16070026
// cycle 93, got UInt<30>(27839200), expect 27839200
// cycle 94, got UInt<30>(39608374), expect 39608374
// cycle 95, got UInt<30>(46882438), expect 46882438
// cycle 96, got UInt<30>(46882438), expect 46882438
// cycle 97, got UInt<30>(39608374), expect 39608374
// cycle 98, got UInt<30>(27839200), expect 27839200
// cycle 99, got UInt<30>(16070026), expect 16070026
// test MyFir Success: 0 tests passed in 107 cycles in 0.066284 seconds 1614.27 Hz
// SUCCESS!!
// window: (Int, Int) => Seq[Int] = ammonite.$sess.cmd9$Helper$$Lambda$3208/0x00007e8164932428@1658406f

// %% [markdown]
// ---
// # Chisel Exercises
// Complete the following exercises to practice writing functions, using them as arguments to hardware generators, and avoiding mutable data.
//
// <span style="color:red">**Exercise: Neural Network Neuron**</span><br>
// Our first example will have you build a neuron, the building block of fully-connected layers in artificial neural networks. Neurons take inputs and a set of weights, one per input, and produce one output. The weights and inputs are multiplied and added, and the result is fed through an activation function. In this exercise, you will implement different activation functions and pass them as an argument to your neuron generator.
//
// <img src="images/ArtificialNeuronModel.png" width="720">
//
// First, complete the following code to create a neuron generator. The parameter `inputs` gives the number of inputs. The parameter `act` is a function that implements the logic of the activation function. We'll make the inputs and outputs 16-bit fixed point values with 8 fractional bits.

// %%
class Neuron(inputs: Int, act: FixedPoint => FixedPoint) extends Module {
  val io = IO(new Bundle {
    val in      = Input(Vec(inputs, FixedPoint(16.W, 8.BP)))
    val weights = Input(Vec(inputs, FixedPoint(16.W, 8.BP)))
    val out     = Output(FixedPoint(16.W, 8.BP))
  })
  
  val netInput = io.in.zip(io.weights).map{case (input:FixedPoint, weight:FixedPoint) => input * weight}.reduce(_ + _)
  io.out := act(netInput)
}
// Out:
// defined class Neuron

// %% [markdown]
// <div id="container"><section id="accordion"><div>
// <input type="checkbox" id="check-2" />
// <label for="check-2"><strong>Solution</strong></label>
// <article>
// <pre style="background-color:#f7f7f7">
//   val mac = io.in.zip(io.weights).map{ case(a:FixedPoint, b:FixedPoint) => a*b}.reduce(_+_)
//   io.out := act(mac)
// </pre></article></div></section></div>

// %% [markdown]
// Now let's create some activation functions! We'll use a threshold of zero. Typical activation functions are the sigmoid function and the rectified linear unit (ReLU).
//
// The sigmoid we'll use is called the [logistic function](https://en.wikipedia.org/wiki/Logistic_function), given by
//
// $logistic(x) = \cfrac{1}{1+e^{-\beta x}}$
//
// where $\beta$ is the slope factor. However, computing the exponential function in hardware is quite challenging and expensive. We'll approximate this as the step function.
//
// $step(x) = \begin{cases}
//              0  & \text{if } x \le 0 \\
//              1  & \text{if } x \gt 0
//        \end{cases}$
//
// The second function, the ReLU, is given by a similar formula.
//
// $relu(x) = \begin{cases}
//              0  & \text{if } x \le 0 \\
//              x  & \text{if } x \gt 0
//        \end{cases}$
//
// Implement these two functions below. You can specify a fixed-point literal like `-3.14.F(8.BP)`.

// %%
// These need to be activation functions in hardware
val Step: FixedPoint => FixedPoint = x => Mux(x <= 0.F(8.BP), 0.F(8.BP), 1.F(8.BP))
val ReLU: FixedPoint => FixedPoint = x => Mux(x <= 0.F(8.BP), 0.F(8.BP), x)
// Out:
// Step: FixedPoint => FixedPoint = ammonite.$sess.cmd15$Helper$$Lambda$5115/0x00007e8164dcc000@5447e12c
// ReLU: FixedPoint => FixedPoint = ammonite.$sess.cmd15$Helper$$Lambda$5116/0x00007e8164dcc3d8@7ad3f130

// %% [markdown]
// <div id="container"><section id="accordion"><div>
// <input type="checkbox" id="check-3" />
// <label for="check-3"><strong>Solution</strong></label>
// <article>
// <pre style="background-color:#f7f7f7">
// val Step: FixedPoint => FixedPoint = x => Mux(x <= 0.F(8.BP), 0.F(8.BP), 1.F(8.BP))
// val ReLU: FixedPoint => FixedPoint = x => Mux(x <= 0.F(8.BP), 0.F(8.BP), x)
// </pre></article></div></section></div>

// %% [markdown]
// Finally, let's create a tester that checks the correctness of our Neuron. With the step activation function, neurons may be used as logic gate approximators. Proper selection of weights and bias can perform binary functions. We'll test our neuron using AND logic. Complete the following tester to check our neuron with the step function.
//
// Note that since the circuit is purely combinational, the `reset(5)` and `step(1)` calls are not necessary.

// %%
// test our Neuron 
test(new Neuron(2, Step)) { c =>
    val inputs = Seq(Seq(-1, -1), Seq(-1, 1), Seq(1, -1), Seq(1, 1))

    // make this a sequence of two values
    val weights = Seq(1.0, 1.0)

    // push data through our Neuron and check the result (AND gate)
    c.reset.poke(true.B)
    c.clock.step(5)
    c.reset.poke(false.B)
    for (i <- inputs) {
        c.io.in(0).poke(i(0).F(8.BP))
        c.io.in(1).poke(i(1).F(8.BP))
        c.io.weights(0).poke(weights(0).F(16.W, 8.BP))
        c.io.weights(1).poke(weights(1).F(16.W, 8.BP))
        c.io.out.expect((if (i(0) + i(1) > 0) 1 else 0).F(16.W, 8.BP))
        c.clock.step(1)
    }
}
println("SUCCESS!!")
// Out:
// test Neuron Success: 0 tests passed in 11 cycles in 0.009119 seconds 1206.22 Hz
// SUCCESS!!

// %% [markdown]
// <div id="container"><section id="accordion"><div>
// <input type="checkbox" id="check-4" />
// <label for="check-4"><strong>Solution</strong></label>
// <article>
// <pre style="background-color:#f7f7f7">
// val weights  = Seq(1.0, 1.0)
// </pre></article></div></section></div>

// %% [markdown]
// ---
// # You're done!
//
// [Return to the top.](#top)
